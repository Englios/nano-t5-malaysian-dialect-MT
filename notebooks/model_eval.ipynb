# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Load model
MODEL_PATH = "../outputs"
device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_PATH)
model = model.to(device)
model.eval()
print("Model loaded!")
# Out:
# Model loaded!

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

def translate(text, max_new_tokens=64, num_beams=4):
    enc = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        max_length=512, 
        padding=False,
    ).to(device)
    
    enc = {k: v.to(device) for k, v in enc.items() if k != "token_type_ids"}

    with torch.no_grad():
        outputs = model.generate(
            **enc,
            max_length=64,
            do_sample=True,
            top_p=0.9,
            temperature=0.7
        )


    return tokenizer.decode(outputs[0], skip_special_tokens=True)

tests = [
    f"{prefix} Saya suka makan nasi"
    for prefix in [
        "terjemah ke johor:",
        "terjemah ke kelantan:",
        "terjemah ke sabah:",
        "terjemah ke sarawak:",
        "terjemah ke kedah:",
        "terjemah ke pahang:",
        "terjemah ke perak:",
        "terjemah ke terengganu:",
        "terjemah ke melaka:",
        "terjemah ke negeri sembilan:",
        "terjemah ke Melayu:",
        "terjemah ke Inggeris:",
        "terjemah ke Manglish:",
    ]
]

for t in tests:
    out = translate(t)
    print("\nINPUT :", t)
    print("OUTPUT:", out)
    print("-" * 60)
# Out:
# INPUT : terjemah ke johor: Saya suka makan nasi
# OUTPUT: 'Horough' with the food!' I'm sure it is the same as the usual food served me. But what is the best of the food?''?''(d) food served me: I'm sorry. It is not the same time as the other way, the food
# ------------------------------------------------------------
#
# INPUT : terjemah ke kelantan: Saya suka makan nasi
# OUTPUT: I suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam. Saya suka makan nasi goreng di pasar malam.
# ------------------------------------------------------------
#
# INPUT : terjemah ke sabah: Saya suka makan nasi
# OUTPUT: Saya suka makan nasi lemak, saya suka makan nasi lemak. Tapi saya suka makan nasi lemak, dan saya suka makan nasi lemak, tapi saya suka makan nasi lemak, tapi saya suka makan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak
# ------------------------------------------------------------
#
# INPUT : terjemah ke sarawak: Saya suka makan nasi
# OUTPUT: I want to be asked to eat the meat and spare meat. I want to eat the meat and spite the meat and spite the meat and springs. I'm not sure what the meat price is like? I want to see it? I want to get it
# ------------------------------------------------------------
#
# INPUT : terjemah ke kedah: Saya suka makan nasi
# OUTPUT: /Bro, aku pun tak paham la tu. Dah tu, aku tak paham betul dengan saya. Saya pun tak paham la, apa kata orang lain pasal makan nasi lemak ayam. I like it is still canteen! Tapi nak cari makan je nasi lemak tu. Saya pun tak paham, tapi takpe
# ------------------------------------------------------------
#
# INPUT : terjemah ke pahang: Saya suka makan nasi
# OUTPUT: I suka makan nasi putih dengan nasi putih. Saya suka makan nasi lemak. Saya suka makan nasi goreng. Saya suka makan nasi lemak. Tapi saya suka makan nasi lemak dengan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak. Saya suka makan nasi lemak dengan nasi lemak
# ------------------------------------------------------------
#
# INPUT : terjemah ke perak: Saya suka makan nasi
# OUTPUT: You can try the meat and eat a noodle with the chicken and duck, but I can't find any dough in the meat and duck with the chicken, and you will be given a snack of chicken and duck with chicken and duck. It's not a snack
# ------------------------------------------------------------
#
# INPUT : terjemah ke terengganu: Saya suka makan nasi
# OUTPUT:  i suka makan nasi lemak, but me prefer to eat more of the same. I can add in more to the price range for me. I'm waiting to try and enjoy me. I'm waiting to eat more of the same time. I am looking for the same price range. I am still waiting for a
# ------------------------------------------------------------
#
# INPUT : terjemah ke melaka: Saya suka makan nasi
# OUTPUT: I suka makan nasi lemak ikan goreng goreng. Saya suka makan nasi goreng dengan nasi goreng. Saya suka makan nasi goreng. Saya suka makan nasi goreng. Saya suka makan nasi goreng. Saya suka makan nasi goreng. Saya suka makan nasi goreng goreng tepung. Saya suka makan nasi goreng. Saya suka makan nasi goreng. Saya
# ------------------------------------------------------------
#
# INPUT : terjemah ke negeri sembilan: Saya suka makan nasi
# OUTPUT: I like the food and the local food is served. I like the food served. I like the food served me. I like the food served me. It's not like that you can try food served. The food served me. I like the food served me. But I like it. I like it.
# ------------------------------------------------------------
#
# INPUT : terjemah ke Melayu: Saya suka makan nasi
# OUTPUT: Saya suka makan nasi goreng dengan ayam goreng. Saya suka makan nasi goreng dengan ayam goreng dengan daging saya. Saya suka makan nasi goreng dengan daging saya. Saya suka makan nasi goreng dengan daging saya. Saya suka makan nasi goreng dengan daging saya. Saya suka makan nasi goreng dengan daging saya. Saya suka makan nasi goreng dengan
# ------------------------------------------------------------
#
# INPUT : terjemah ke Inggeris: Saya suka makan nasi
# OUTPUT: I like a cockle, but can't take anymore of the food. I like a cockle, but cannot eat a dish. I like a cockle, and can't eat the food. But I like to eat the cockle and eat the cough. I like a c
# ------------------------------------------------------------
#
# INPUT : terjemah ke Manglish: Saya suka makan nasi
# OUTPUT: I like a snack of fish and a snack. I'm trying to get a snack.
# ------------------------------------------------------------
